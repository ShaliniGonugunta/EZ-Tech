# %%
def knapsack(capacity, weights, values, n):
    K = [[0 for x in range(capacity + 1)] for x in range(n + 1)]

    for i in range(n + 1):
        for w in range(capacity + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif weights[i-1] <= w:
                K[i][w] = max(values[i-1] + K[i-1][w-weights[i-1]], K[i-1][w])
            else:
                K[i][w] = K[i-1][w]

    return K[n][capacity]


def main():
    n = int(input("Enter the number of items: "))
    weights = []
    values = []
    for i in range(n):
        weight = int(input(f"Enter weight of item {i+1}: "))
        value = int(input(f"Enter profit/value of item {i+1}: "))
        weights.append(weight)
        values.append(value)
    capacity = int(input("Enter the capacity of the knapsack: "))

    max_value = knapsack(capacity, weights, values, n)
    print(f"The maximum value/profit that can be put in a knapsack of capacity {capacity} is {max_value}")

if __name__ == "__main__":
    main()
# Out:
# Enter the number of items: 7
# Enter weight of item 1: 1
# Enter profit/value of item 1: 5
# Enter weight of item 2: 3
# Enter profit/value of item 2: 10
# Enter weight of item 3: 5
# Enter profit/value of item 3: 15
# Enter weight of item 4: 4
# Enter profit/value of item 4: 7
# Enter weight of item 5: 1
# Enter profit/value of item 5: 8
# Enter weight of item 6: 3
# Enter profit/value of item 6: 9
# Enter weight of item 7: 2
# Enter profit/value of item 7: 4
# Enter the capacity of the knapsack: 15
# The maximum value that can be put in a knapsack of capacity 15 is 51

# %%
def knapsack(capacity, weights, values, n):
    K = [[0 for x in range(capacity + 1)] for x in range(n + 1)]

    for i in range(n + 1):
        for w in range(capacity + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif weights[i-1] <= w:
                K[i][w] = max(values[i-1] + K[i-1][w-weights[i-1]], K[i-1][w])
            else:
                K[i][w] = K[i-1][w]

    res = K[n][capacity]
    w = capacity
    items_selected = [0] * n

    for i in range(n, 0, -1):
        if res <= 0:
            break
        if res == K[i-1][w]:
            continue
        else:
            items_selected[i-1] = 1
            res = res - values[i-1]
            w = w - weights[i-1]

    return K[n][capacity], items_selected

def main():
    n = int(input("Enter the number of items: "))
    weights = []
    values = []
    for i in range(n):
        weight = int(input(f"Enter weight of item {i+1}: "))
        value = int(input(f"Enter value of item {i+1}: "))
        weights.append(weight)
        values.append(value)
    capacity = int(input("Enter the capacity of the knapsack: "))

    max_value, items_selected = knapsack(capacity, weights, values, n)
    print(f"The maximum value that can be put in a knapsack of capacity {capacity} is {max_value}")
    print("Items selected (1 for selected, 0 for not selected):")
    print(items_selected)

if __name__ == "__main__":
    main()
# Out:
# Enter the number of items: 7
# Enter weight of item 1: 1
# Enter value of item 1: 5
# Enter weight of item 2: 3
# Enter value of item 2: 10
# Enter weight of item 3: 5
# Enter value of item 3: 15
# Enter weight of item 4: 4
# Enter value of item 4: 7
# Enter weight of item 5: 1
# Enter value of item 5: 8
# Enter weight of item 6: 3
# Enter value of item 6: 9
# Enter weight of item 7: 2
# Enter value of item 7: 4
# Enter the capacity of the knapsack: 15
# The maximum value that can be put in a knapsack of capacity 15 is 51
# Items selected (1 for selected, 0 for not selected):
# [1, 1, 1, 0, 1, 1, 1]

# %%
def knapsack(capacity, weights, values, n):
    K = [[0 for x in range(capacity + 1)] for x in range(n + 1)]

    for i in range(n + 1):
        for w in range(capacity + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif weights[i-1] <= w:
                K[i][w] = max(values[i-1] + K[i-1][w-weights[i-1]], K[i-1][w])
            else:
                K[i][w] = K[i-1][w]

    res = K[n][capacity]
    w = capacity
    items_selected = [0] * n

    for i in range(n, 0, -1):
        if res <= 0:
            break
        if res == K[i-1][w]:
            continue
        else:
            items_selected[i-1] = 1
            res = res - values[i-1]
            w = w - weights[i-1]

    return K[n][capacity], items_selected

def main():
    n = int(input("Enter the number of items: "))
    weights = []
    values = []
    for i in range(n):
        weight = int(input(f"Enter weight of item {i+1}: "))
        value = int(input(f"Enter value of item {i+1}: "))
        weights.append(weight)
        values.append(value)
    capacity = int(input("Enter the capacity of the knapsack: "))

    max_value, items_selected = knapsack(capacity, weights, values, n)
    print("The maximum value that can be put in a knapsack of capacity {capacity} is {max_value}")
    print("Items selected (1 for selected, 0 for not selected):")
    print(items_selected)

if __name__ == "__main__":
    main()
# Out:
# Enter the number of items: 2
# Enter weight of item 1: 1
# Enter value of item 1: 30
# Enter weight of item 2: 3
# Enter value of item 2: 10
# Enter the capacity of the knapsack: 25
# The maximum value that can be put in a knapsack of capacity {capacity} is {max_value}
# Items selected (1 for selected, 0 for not selected):
# [1, 1]

# %%
def knapsack(capacity, weights, values, n):
    K = [[0 for x in range(capacity + 1)] for x in range(n + 1)]

    for i in range(n + 1):
        for w in range(capacity + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif weights[i] <= w:
                K[i][w] = max(values[i] + K[i-1][w-weights[i]], K[i-1][w])
            else:
                K[i][w] = K[i-1][w]

    res = K[n][capacity]
    w = capacity
    items_selected = {i: 0 for i in range(n)}

    for i in range(n, 0, -1):
        if res <= 0:
            break
        if res == K[i-1][w]:
            continue
        else:
            items_selected[i-1] = 1
            res = res - values[i]
            w = w - weights[i]

    return K[n][capacity], items_selected

def main():
    n = int(input("Enter the number of items: "))
    weights = {}
    values = {}
    for i in range(n):
        weight = int(input(f"Enter weight of item {i+1}: "))
        value = int(input(f"Enter value of item {i+1}: "))
        weights[i] = weight
        values[i] = value
    capacity = int(input("Enter the capacity of the knapsack: "))

    max_value, items_selected = knapsack(capacity, weights, values, n)
    print(f"The maximum value that can be put in a knapsack of capacity {capacity} is {max_value}")
    print("Items selected (1 for selected, 0 for not selected):")
    print(items_selected)

if __name__ == "__main__":
    main()
